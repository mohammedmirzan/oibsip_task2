# %% [markdown]
# # Iris Flower Classification with Python

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Lets load the Boston House Pricing dataset

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %% [markdown]
# ## Check the description of the dataset

# %%
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
#Feature names

print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
#Target names
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
print(iris.data)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
dataset = pd.DataFrame(iris.data, columns=iris.feature_names)

# %% [markdown]
# ## Summarize and Analyize the dataset

# %%
dataset.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
dataset["Iris Class"]=iris.target

# %%
dataset.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Iris Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
dataset.keys()
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'Iris Class'],
#       dtype='object')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Iris Class         150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %%
# Summarize the dataset
dataset.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)  Iris Class
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
# Check the missing values

dataset.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# Iris Class           0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Correlation
dataset_corr = dataset.corr().round(2)
dataset_corr
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)               1.00             -0.12               0.87
# sepal width (cm)               -0.12              1.00              -0.43
# petal length (cm)               0.87             -0.43               1.00
# petal width (cm)                0.82             -0.37               0.96
# Iris Class                      0.78             -0.43               0.95
#
#                    petal width (cm)  Iris Class
# sepal length (cm)              0.82        0.78
# sepal width (cm)              -0.37       -0.43
# petal length (cm)              0.96        0.95
# petal width (cm)               1.00        0.96
# Iris Class                     0.96        1.00

# %%
plt.figure(figsize=(5,4))
sns.heatmap(dataset_corr, annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
plt.scatter(dataset['sepal length (cm)'], dataset['Iris Class'])

# %%
plt.scatter(dataset['petal length (cm)'], dataset['Iris Class'])

# %%
plt.scatter(dataset['sepal width (cm)'], dataset['Iris Class'])

# %%
plt.scatter(dataset['petal width (cm)'], dataset['Iris Class'])

# %%
# Independent and Dependent Features

X = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Iris Class, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
X_train
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 120                6.9               3.2                5.7               2.3
# 25                 5.0               3.0                1.6               0.2
# 72                 6.3               2.5                4.9               1.5
# 54                 6.5               2.8                4.6               1.5
# 130                7.4               2.8                6.1               1.9
# ..                 ...               ...                ...               ...
# 86                 6.7               3.1                4.7               1.5
# 28                 5.2               3.4                1.4               0.2
# 84                 5.4               3.0                4.5               1.5
# 62                 6.0               2.2                4.0               1.0
# 148                6.2               3.4                5.4               2.3
#
# [105 rows x 4 columns]

# %%
X_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 122                7.7               2.8                6.7               2.0
# 127                6.1               3.0                4.9               1.8
# 92                 5.8               2.6                4.0               1.2
# 143                6.8               3.2                5.9               2.3
# 2                  4.7               3.2                1.3               0.2
# 128                6.4               2.8                5.6               2.1
# 53                 5.5               2.3                4.0               1.3
# 46                 5.1               3.8                1.6               0.2
# 133                6.3               2.8                5.1               1.5
# 132                6.4               2.8                5.6               2.2
# 36                 5.5               3.5                1.3               0.2
# ...

# %% [markdown]
# ## Apply Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.9777777777777777

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([2, 2, 1, 2, 0, 2, 1, 0, 1, 2, 0, 2, 2, 1, 0, 1, 1, 1, 1, 1, 0, 2,
#        0, 1, 1, 0, 0, 2, 0, 0, 0, 0, 1, 2, 2, 2, 0, 2, 1, 2, 2, 1, 1, 2,
#        2])

# %% [markdown]
# ## Performance Metrics

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix = confusion_matrix(y_test,y_pred)
confusion_matrix
# Out:
# array([[13,  0,  0],
#        [ 0, 14,  0],
#        [ 0,  1, 17]], dtype=int64)

# %%
plt.figure(figsize=(5,4))
sns.heatmap(confusion_matrix, annot=True)
plt.xlabel("Predicted")
plt.ylabel("Truth")
# Out:
# Text(33.22222222222222, 0.5, 'Truth')

# %%
from sklearn.metrics import accuracy_score, mean_absolute_error
accuracy = accuracy_score(y_test,y_pred)
mean_absolute_error = mean_absolute_error(y_test,y_pred)
mean_absolute_error
# Out:
# 0.022222222222222223

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
scatter = ax.scatter(iris.data[:, 0], iris.data[:, 1], c=iris.target)
ax.set(xlabel=iris.feature_names[0], ylabel=iris.feature_names[1])
fig = ax.legend(
    scatter.legend_elements()[0], iris.target_names, loc="lower right", title="Classes"
)

# %% [markdown]
# ## Apply K-Nearest Neighbors Classifier

# %%
# Use KNN 
from sklearn.neighbors import KNeighborsClassifier
model1 = KNeighborsClassifier()

# %%
model1.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Performance metrics for KNN

# %%
model1.score(X_test,y_test)
# Out:
# 0.9333333333333333
